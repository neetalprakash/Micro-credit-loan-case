# %% [markdown]
# # MICRO CREDIT PROJECT

# %% [markdown]
# Loading the modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# loading the Dataset

# %%
mcp=pd.read_csv("micro_project",sep="\t")

# %%
mcp
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %% [markdown]
# 209593 rows and 37 columns in Micro credit project.

# %%
mcp.head(5).T
# Out:
#                                 0            1            2            3  \
# Unnamed: 0                      1            2            3            4
# label                           0            1            1            1
# msisdn                21408I70789  76462I70374  17943I70372  55773I70781
# aon                         272.0        712.0        535.0        241.0
# daily_decr30              3055.05      12122.0       1398.0       21.228
# daily_decr90              3065.15     12124.75       1398.0       21.228
# rental30                   220.13      3691.26       900.13       159.42
# rental90                   260.13      3691.26       900.13       159.42
# last_rech_date_ma             2.0         20.0          3.0         41.0
# last_rech_date_da             0.0          0.0          0.0          0.0
# last_rech_amt_ma             1539         5787         1539          947
# cnt_ma_rech30                   2            1            1            0
# ...

# %% [markdown]
# Fisrt 5 rows with all columns.

# %%
mcp.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %% [markdown]
# There are int,float and object types of data.

# %%
mcp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# 21 float 13 int and 3 object data types in micro credit project.

# %%
mcp.keys()
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# All features name of the Dataset.

# %%
mcp.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# NO null values in Dataset.

# %%
sns.heatmap(mcp.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# No balnks in heatmap it means no null values in Dataset.

# %% [markdown]
# # Statistical Summary

# %%
mcp.describe().T
# Out:
#                          count           mean           std           min  \
# Unnamed: 0            209593.0  104797.000000  60504.431823      1.000000
# label                 209593.0       0.875177      0.330519      0.000000
# aon                   209593.0    8112.343445  75696.082531    -48.000000
# daily_decr30          209593.0    5381.402289   9220.623400    -93.012667
# daily_decr90          209593.0    6082.515068  10918.812767    -93.012667
# rental30              209593.0    2692.581910   4308.586781 -23737.140000
# rental90              209593.0    3483.406534   5770.461279 -24720.580000
# last_rech_date_ma     209593.0    3755.847800  53905.892230    -29.000000
# last_rech_date_da     209593.0    3712.202921  53374.833430    -29.000000
# last_rech_amt_ma      209593.0    2064.452797   2370.786034      0.000000
# cnt_ma_rech30         209593.0       3.978057      4.256090      0.000000
# fr_ma_rech30          209593.0    3737.355121  53643.625172      0.000000
# ...

# %% [markdown]
# Observation;
#
# High variance in mean and median value and high variance in 75% and 100% in most of the columns, it means data are skewed.

# %%
mcp.corr().sum().sort_values(ascending=False)
# Out:
# sumamnt_ma_rech90       8.685847
# sumamnt_ma_rech30       8.218907
# daily_decr30            8.168585
# daily_decr90            8.027381
# cnt_ma_rech90           7.433849
# amnt_loans90            7.356221
# amnt_loans30            7.082513
# cnt_ma_rech30           6.842523
# cnt_loans30             6.274226
# rental90                5.689272
# rental30                5.587737
# medianamnt_ma_rech30    5.083272
# last_rech_amt_ma        4.819792
# maxamnt_loans90         4.774383
# medianamnt_ma_rech90    4.706931
# label                   3.728495
# payback90               2.286104
# payback30               2.209210
# medianmarechprebal90    1.807033
# cnt_da_rech90           1.776599
# medianamnt_loans30      1.699946
# fr_da_rech90            1.618694
# medianamnt_loans90      1.426598
# cnt_loans90             1.130278
# aon                     1.019633
# maxamnt_loans30         1.016339
# cnt_da_rech30           1.014475
# last_rech_date_da       1.010773
# ...

# %% [markdown]
# observation;
#
# sumamnt_ma_rech90, sumamnt_ma_rech30, daily_decr30 and daily_decr90 these column are highly correlated with the label.
# and Unnamed: 0, medianmarechprebal30, fr_da_rech30 and fr_ma_rech90 these columns are very less correlated with the laebel.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(mcp.corr())
# Out:
# <AxesSubplot: >

# %% [markdown]
# We can see by the graph also that daily_decr30, daily_decr90, cnt_ma_rech90,sumamnt_ma_rech90, sumamnt_ma_rech30 all these independent variables are have good correlation.

# %% [markdown]
# # DATA VISUALIZATION OR EDA

# %%
mcp.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
mcp["Unnamed: 0"].value_counts()
# Out:
# 1         1
# 139733    1
# 139723    1
# 139724    1
# 139725    1
#          ..
# 69869     1
# 69870     1
# 69871     1
# 69872     1
# 209593    1
# Name: Unnamed: 0, Length: 209593, dtype: int64

# %% [markdown]
# Unnamed: 0 is just a serial no of columns, it does not important for y label, so we can drop this column.

# %%
mcp.drop("Unnamed: 0",axis=1,inplace=True)

# %%
mcp.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# Unnamed: 0 column has been dropped.

# %%
mcp["msisdn"].value_counts()
# Out:
# 04581I85330    7
# 47819I90840    7
# 30080I90588    6
# 55809I89238    6
# 22038I88658    6
#               ..
# 36902I90840    1
# 17447I88689    1
# 59686I90584    1
# 00504I91190    1
# 65061I85339    1
# Name: msisdn, Length: 186243, dtype: int64

# %% [markdown]
# msisdn is mobile number of user,it will not affect the label so we can drop this column.

# %%
mcp.drop("msisdn",axis=1,inplace=True)

# %%
mcp.keys()
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# msisdn column has been dropped.

# %%
mcp["label"].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
plt.violinplot(mcp["label"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x213c385b760>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x213c2bda070>,
#  'cmins': <matplotlib.collections.LineCollection at 0x213c385bd60>,
#  'cbars': <matplotlib.collections.LineCollection at 0x213c3762100>}

# %% [markdown]
# label means (Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
# )
#
# So out of 209593 people, 183431 people have success to take the credit amount and 26162 people have failure to take the credit amount.

# %%
mcp["aon"].value_counts()
# Out:
# 95.0000        392
# 92.0000        362
# 96.0000        357
# 99.0000        356
# 157.0000       349
#               ...
# 977092.3520      1
# 645851.0384      1
# 881623.8154      1
# 555267.7977      1
# 811881.3728      1
# Name: aon, Length: 4507, dtype: int64

# %%
sns.catplot(x="aon",data=mcp)

# %% [markdown]
# aon(age on cellular network in days) is highest in 0.5 to 1.0.

# %%
mcp["daily_decr30"].value_counts()
# Out:
# 0.000000       4144
# 500.000000      829
# 1000.000000     569
# 700.000000      381
# 600.000000      354
#                ...
# 3679.110667       1
# 6940.330000       1
# 4878.826667       1
# 5110.382000       1
# 4489.362000       1
# Name: daily_decr30, Length: 146328, dtype: int64

# %%
sns.violinplot(x="daily_decr30",data=mcp)
# Out:
# <AxesSubplot: xlabel='daily_decr30'>

# %% [markdown]
# 0 to 1000 values are higher in daily_decr30(Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
# )

# %%
sns.scatterplot(x="daily_decr30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='daily_decr30', ylabel='label'>

# %% [markdown]
# 1(success) people have 0 to 180000 daily_decr30(Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
# ) and 0(failure) people have 0 to 80000 daily_decr30(Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah).

# %%
mcp["daily_decr90"].value_counts()
# Out:
# 0.000000        4063
# 500.000000       782
# 1000.000000      490
# 700.000000       343
# 600.000000       319
#                 ...
# 36454.750000       1
# 5099.050000        1
# 22.095333          1
# 12690.450000       1
# 4534.820000        1
# Name: daily_decr90, Length: 155483, dtype: int64

# %%
sns.histplot(mcp["daily_decr90"])
# Out:
# <AxesSubplot: xlabel='daily_decr90', ylabel='Count'>

# %% [markdown]
# 0 to 1000 values are higher in daily_decr90(Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
# )

# %%
sns.scatterplot(x="daily_decr90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='daily_decr90', ylabel='label'>

# %% [markdown]
# 1 type of people have 0 to 250000 daily_decr90(Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah) )
#
# and 0 type of people have 0 to 80000 daily_decr90(Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah).

# %%
mcp["rental30"].value_counts()
# Out:
# 0.00       7566
# 200.13     1379
# 99.56      1020
# 400.26      530
# 199.12      461
#            ...
# 824.85        1
# 517.35        1
# 6526.31       1
# 4184.14       1
# 483.92        1
# Name: rental30, Length: 131338, dtype: int64

# %%
sns.distplot(mcp["rental30"])
# Out:
# <AxesSubplot: xlabel='rental30', ylabel='Density'>

# %% [markdown]
# 0 to 1000 values are higher in rental30(Average main account balance over last 30 days)

# %%
sns.histplot(y="rental30",x="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='label', ylabel='rental30'>

# %% [markdown]
# 1(success) people have 0 to 50000 rental30(Average main account balance over last 30 days)
# and 0(failure) people have 0 to 30000 rental30(Average main account balance over last 30 days).

# %%
#pd.set_option("display.max_rows",None)

# %%
mcp["rental90"].value_counts()
# Out:
# 0.00       6918
# 200.13      913
# 99.56       767
# 60.00       691
# 90.00       685
#            ...
# 1149.63       1
# 200.31        1
# 303.49        1
# 4675.78       1
# 984.58        1
# Name: rental90, Length: 139036, dtype: int64

# %%
sns.violinplot(x="rental90",data=mcp)
# Out:
# <AxesSubplot: xlabel='rental90'>

# %% [markdown]
# 0 to 1000 values are higher in rental90(Average main account balance over last 90 days)

# %%
sns.displot(y="rental90",x="label",data=mcp)

# %% [markdown]
# 1(success) people have 0 to 80000 rental90(Average main account balance over last 90 days) and 0(failure) people have 0 to 50000 rental90(Average main account balance over last 90 days).

# %%
mcp["last_rech_date_ma"].value_counts()
# Out:
# 1.0000         47343
# 2.0000         26665
# 0.0000         20743
# 3.0000         19984
# 4.0000         15452
#                ...
# 972385.2702        1
# 800187.0537        1
# 851900.0411        1
# 679670.4904        1
# 590843.1220        1
# Name: last_rech_date_ma, Length: 1186, dtype: int64

# %%
sns.catplot(x="last_rech_date_ma",data=mcp)

# %%
mcp["last_rech_date_da"].value_counts()
# Out:
# 0.0000         202861
# 7.0000            163
# 8.0000            160
# 11.0000           149
# 13.0000           148
#                 ...
# 731116.8745         1
# 609105.6623         1
# 945424.2537         1
# 505559.4527         1
# 636529.1273         1
# Name: last_rech_date_da, Length: 1174, dtype: int64

# %% [markdown]
# 0 last_rech_date_da(Number of days till last recharge of data account) is highest.

# %%
sns.catplot(x="last_rech_date_da",data=mcp)

# %%
mcp["last_rech_amt_ma"].value_counts()
# Out:
# 1539     56297
# 770      41766
# 0        20995
# 773      19523
# 2309     16113
#          ...
# 4066         1
# 15652        1
# 772          1
# 34783        1
# 10454        1
# Name: last_rech_amt_ma, Length: 70, dtype: int64

# %%
sns.violinplot(mcp["last_rech_amt_ma"])
# Out:
# <AxesSubplot: >

# %% [markdown]
# last_rech_amt_ma(Amount of last recharge of main account (in Indonesian Rupiah)) is higher in between 0 to 10000.

# %%
sns.jointplot(x="last_rech_amt_ma",y="label",data=mcp)

# %% [markdown]
# 1(success) people have 0 to 25000 last_rech_amt_ma(Amount of last recharge of main account (in Indonesian Rupiah)) and 0(failure) people have 0 to 18000 last_rech_amt_ma(Amount of last recharge of main account (in Indonesian Rupiah)).

# %%
mcp["cnt_ma_rech30"].value_counts()
# Out:
# 1     37238
# 2     31216
# 0     27979
# 3     25519
# 4     20258
#       ...
# 84        1
# 59        1
# 64        1
# 74        1
# 63        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64

# %%
sns.histplot(mcp["cnt_ma_rech30"])
# Out:
# <AxesSubplot: xlabel='cnt_ma_rech30', ylabel='Count'>

# %% [markdown]
# cnt_ma_rech30(Number of times main account got recharged in last 30 days) data is high in between 0 to 10.

# %%
sns.histplot(x="label",y="cnt_ma_rech30",data=mcp)
# Out:
# <AxesSubplot: xlabel='label', ylabel='cnt_ma_rech30'>

# %% [markdown]
# 1(success), cnt_ma_rech30(Number of times main account got recharged in last 30 days) data is high in between 0 to 100.
#
# and 0(failure), cnt_ma_rech30(Number of times main account got recharged in last 30 days) data is high in between 0 to 25.

# %%
mcp["fr_ma_rech30"].value_counts()
# Out:
# 0.0000         78683
# 1.0000         22370
# 2.0000         18849
# 3.0000         14306
# 4.0000         11194
#                ...
# 967338.1316        1
# 779697.8460        1
# 723333.5198        1
# 891246.0040        1
# 747564.0753        1
# Name: fr_ma_rech30, Length: 1083, dtype: int64

# %%
sns.catplot(x="fr_ma_rech30",data=mcp)

# %%
sns.scatterplot(x="fr_ma_rech30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='fr_ma_rech30', ylabel='label'>

# %%
mcp["sumamnt_ma_rech30"].value_counts()
# Out:
# 0.0        27979
# 1539.0      9006
# 770.0       6040
# 773.0       4540
# 2309.0      4509
#            ...
# 40924.0        1
# 38412.0        1
# 22899.0        1
# 5381.0         1
# 12154.0        1
# Name: sumamnt_ma_rech30, Length: 15141, dtype: int64

# %%
sns.violinplot(x="sumamnt_ma_rech30",data=mcp)
# Out:
# <AxesSubplot: xlabel='sumamnt_ma_rech30'>

# %% [markdown]
# sumamnt_ma_rech30(Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)) data is higher in 0 to 10000.

# %%
sns.scatterplot(x="sumamnt_ma_rech30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='sumamnt_ma_rech30', ylabel='label'>

# %% [markdown]
# 0(failure), sumamnt_ma_rech30(Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)) data is high in between 0 to 10000.
# 1(success), sumamnt_ma_rech30(Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)) data is high in between 0 to 300000.

# %%
mcp["medianamnt_ma_rech30"].value_counts()
# Out:
# 1539.0     47769
# 770.0      30754
# 0.0        27979
# 773.0      22680
# 2309.0     11177
#            ...
# 2690.5         1
# 4729.5         1
# 4742.0         1
# 3566.5         1
# 10963.5        1
# Name: medianamnt_ma_rech30, Length: 510, dtype: int64

# %%
sns.distplot(mcp["medianamnt_ma_rech30"])
# Out:
# <AxesSubplot: xlabel='medianamnt_ma_rech30', ylabel='Density'>

# %% [markdown]
# medianamnt_ma_rech30(Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah))
# data is high in 0 to 10000.

# %%
sns.jointplot(x="medianamnt_ma_rech30",y="label",data=mcp)

# %% [markdown]
# 0(success), medianamnt_ma_rech30(Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)) data is high in 0 to 20000.
#
# 1(failure), medianamnt_ma_rech30(Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)) data is high in 0 to 25000.

# %%
mcp["medianmarechprebal30"].value_counts()
# Out:
# 0.00      30680
# 20.00      1108
# 19.00      1091
# 17.00      1060
# 10.00      1045
#           ...
# 503.21        1
# 242.55        1
# 451.51        1
# 238.34        1
# 71.37         1
# Name: medianmarechprebal30, Length: 23907, dtype: int64

# %%
sns.catplot(x="medianmarechprebal30",data=mcp)

# %%
sns.scatterplot(x="medianmarechprebal30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianmarechprebal30', ylabel='label'>

# %% [markdown]
# medianmarechprebal30(Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)) data is almost same in both 1(success)and 0(failure)

# %%
mcp["cnt_ma_rech90"].value_counts()
# Out:
# 1      27898
# 2      24052
# 0      20950
# 3      20446
# 4      17329
#        ...
# 105        1
# 110        1
# 140        1
# 94         1
# 120        1
# Name: cnt_ma_rech90, Length: 110, dtype: int64

# %%
sns.distplot(mcp["cnt_ma_rech90"])
# Out:
# <AxesSubplot: xlabel='cnt_ma_rech90', ylabel='Density'>

# %% [markdown]
# Distribution of cnt_ma_rech90(Number of times main account got recharged in last 90 days) data is high in between 0 to 50.

# %%
mcp["fr_ma_rech90"].value_counts()
# Out:
# 0     65753
# 1     24373
# 2     19285
# 3     13192
# 4     10021
#       ...
# 80        7
# 81        7
# 88        5
# 84        4
# 87        1
# Name: fr_ma_rech90, Length: 89, dtype: int64

# %%
plt.violinplot(mcp["fr_ma_rech90"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x213e8d6daf0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x213e8d6da60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x213e8d7f130>,
#  'cbars': <matplotlib.collections.LineCollection at 0x213e8d7f490>}

# %% [markdown]
# fr_ma_rech90(Frequency of main account recharged in last 90 days) data is high in 0 to 20.

# %%
sns.histplot(x="fr_ma_rech90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='fr_ma_rech90', ylabel='label'>

# %% [markdown]
# frequency of fr_ma_rech90(Frequency of main account recharged in last 90 days) data is same in both 1 and 0 type of label.

# %%
mcp["sumamnt_ma_rech90"].value_counts()
# Out:
# 0        20950
# 1539      5631
# 773       4177
# 770       3982
# 2309      2542
#          ...
# 32427        1
# 71229        1
# 78428        1
# 8241         1
# 17941        1
# Name: sumamnt_ma_rech90, Length: 31771, dtype: int64

# %%
sns.distplot(mcp["sumamnt_ma_rech90"])
# Out:
# <AxesSubplot: xlabel='sumamnt_ma_rech90', ylabel='Density'>

# %% [markdown]
# distribution of sumamnt_ma_rech90(Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)) data is high in 0.0 to 0.1.

# %%
sns.jointplot(x="sumamnt_ma_rech90",y="label",data=mcp)

# %% [markdown]
# 0(failure) data is high in 0.0 to 0.2 .
# and 1(success) data is high in 0.0 to 0.5 .

# %%
mcp["medianamnt_ma_rech90"].value_counts()
# Out:
# 1539.0     45780
# 773.0      30543
# 770.0      23844
# 0.0        20950
# 2309.0     10665
#            ...
# 8708.5         1
# 6350.0         1
# 4700.0         1
# 6818.0         1
# 10963.5        1
# Name: medianamnt_ma_rech90, Length: 608, dtype: int64

# %%
sns.histplot(mcp["medianamnt_ma_rech90"])
# Out:
# <AxesSubplot: xlabel='medianamnt_ma_rech90', ylabel='Count'>

# %% [markdown]
# Frequency of medianamnt_ma_rech90(Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)) data is high in 0 to 10000 .

# %%
sns.scatterplot(x="medianamnt_ma_rech90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianamnt_ma_rech90', ylabel='label'>

# %% [markdown]
# 0(failure) data is high in 0 to 18000 . and 1(success) data is high in 0 to 24000.

# %%
mcp["medianmarechprebal90"].value_counts()
# Out:
#  0.00      23391
#  20.00      1265
#  19.00      1208
#  26.00      1171
#  27.00      1166
#            ...
# -146.52        1
#  317.17        1
#  432.67        1
#  55.28         1
#  392.20        1
# Name: medianmarechprebal90, Length: 22694, dtype: int64

# %%
sns.violinplot(x="medianmarechprebal90",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianmarechprebal90'>

# %% [markdown]
# medianmarechprebal90(Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)) is higher 0 to 1000 .

# %%
sns.histplot(x="medianmarechprebal90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianmarechprebal90', ylabel='label'>

# %% [markdown]
# 1(success) medianmarechprebal90(Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)) is high in 0 to 4000 and 0(failure) medianmarechprebal90(Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)) is high in between 0 to 1000.

# %%
mcp["cnt_da_rech30"].value_counts()
# Out:
# 0.00000        205479
# 1.00000          2331
# 2.00000           372
# 3.00000           156
# 4.00000            86
#                 ...
# 13710.64367         1
# 84844.56285         1
# 65385.40352         1
# 93840.66307         1
# 61002.42135         1
# Name: cnt_da_rech30, Length: 1066, dtype: int64

# %%
sns.histplot(mcp["cnt_da_rech30"])
# Out:
# <AxesSubplot: xlabel='cnt_da_rech30', ylabel='Count'>

# %% [markdown]
# cnt_da_rech30(Number of times data account got recharged in last 30 days) is highest in 0.

# %%
sns.displot(x="cnt_da_rech30",y="label",data=mcp)

# %% [markdown]
# 1(success) and 0(failure) both have almost same, cnt_da_rech30(Number of times data account got recharged in last 30 days) data.

# %%
mcp["fr_da_rech30"].value_counts()
# Out:
# 0.0000         208014
# 3.0000             64
# 1.0000             55
# 2.0000             51
# 7.0000             47
#                 ...
# 757900.5305         1
# 870976.4775         1
# 797647.0019         1
# 519699.8854         1
# 509386.3027         1
# Name: fr_da_rech30, Length: 1072, dtype: int64

# %%
sns.histplot(mcp["fr_da_rech30"])
# Out:
# <AxesSubplot: xlabel='fr_da_rech30', ylabel='Count'>

# %% [markdown]
# Frequency of fr_da_rech30(Frequency of data account recharged in last 30 days) is higest in 0.0.

# %%
sns.jointplot(x="fr_da_rech30",y="label",data=mcp)

# %% [markdown]
# 1(success) fr_da_rech30(Frequency of data account recharged in last 30 days) is higher than 0(failure), fr_da_rech30(Frequency of data account recharged in last 30 days).

# %%
mcp["cnt_da_rech90"].value_counts()
# Out:
# 0     204226
# 1       4173
# 2        556
# 3        227
# 4        150
# 5         74
# 6         49
# 7         36
# 8         30
# 9         18
# 14        10
# 12         7
# 11         7
# 13         6
# 10         6
# 16         4
# 18         3
# 15         2
# 20         1
# 25         1
# 28         1
# 30         1
# 22         1
# 38         1
# 19         1
# 27         1
# 17         1
# Name: cnt_da_rech90, dtype: int64

# %%
sns.violinplot(x="cnt_da_rech90",data=mcp)
# Out:
# <AxesSubplot: xlabel='cnt_da_rech90'>

# %% [markdown]
# cnt_da_rech90(Number of times data account got recharged in last 90 days) is highest in 0.

# %%
sns.lineplot(x="cnt_da_rech90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='cnt_da_rech90', ylabel='label'>

# %% [markdown]
# 1(success), cnt_da_rech90(Number of times data account got recharged in last 90 days) is higher than 0(failure).

# %%
mcp["fr_da_rech90"].value_counts()
# Out:
# 0     208728
# 3         78
# 1         66
# 2         66
# 4         56
# 7         55
# 6         52
# 5         45
# 8         44
# 10        33
# 14        32
# 9         32
# 11        30
# 12        27
# 19        22
# 28        19
# 15        17
# 13        17
# 18        16
# 29        15
# 16        14
# 17        14
# 25        11
# 22        11
# 21        10
# 20         9
# 32         8
# 24         8
# 27         8
# 26         7
# 30         7
# 31         6
# 34         5
# 37         5
# 23         5
# 57         3
# 35         2
# 41         2
# 42         1
# 39         1
# 33         1
# 43         1
# 56         1
# 46         1
# 55         1
# 64         1
# Name: fr_da_rech90, dtype: int64

# %% [markdown]
# fr_da_rech90(Frequency of data account recharged in last 90 days) is higher in 0.

# %%
sns.catplot(x="fr_da_rech90",y="label",data=mcp,aspect=2,marker="X")

# %% [markdown]
# 0(failure), fr_da_rech90(Frequency of data account recharged in last 90 days) is in between 0 to 35 and 1(success), fr_da_rech90(Frequency of data account recharged in last 90 days) is in between 0 to 64.

# %%
mcp["cnt_loans30"].value_counts()
# Out:
# 1     83432
# 2     42665
# 3     27050
# 4     17499
# 5     11673
# 6      7773
# 7      5041
# 8      3384
# 0      3259
# 9      2273
# 10     1571
# 11     1143
# 12      793
# 13      547
# 14      383
# 15      270
# 16      213
# 17      164
# 18       98
# 19       77
# 20       54
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 30        4
# 32        4
# 33        3
# 38        2
# 36        1
# 41        1
# 44        1
# 50        1
# 35        1
# Name: cnt_loans30, dtype: int64

# %%
sns.catplot(x="cnt_loans30",data=mcp)

# %% [markdown]
# cnt_loans30(Number of loans taken by user in last 30 days) is higher in between 0 to 20.

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x="cnt_loans30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='cnt_loans30', ylabel='label'>

# %% [markdown]
# cnt_loans30(Number of loans taken by user in last 30 days) data is higher in 1(success) type of label.

# %%
mcp["amnt_loans30"].value_counts()
# Out:
# 6      76620
# 12     44384
# 18     26379
# 24     18403
# 30     11999
# 36      8559
# 42      5580
# 48      3994
# 0       3259
# 54      2660
# 60      2043
# 66      1402
# 72      1101
# 78       742
# 84       580
# 90       394
# 96       333
# 102      252
# 108      182
# 114      135
# 120      119
# 132       92
# 126       80
# 138       64
# 156       34
# 150       30
# 144       30
# 162       29
# 168       20
# 174       17
# 186       15
# 180       13
# 192        7
# 198        6
# 252        4
# 210        4
# 228        4
# 216        4
# 222        3
# 258        3
# 264        3
# 276        3
# 240        2
# 204        2
# 246        1
# 300        1
# 270        1
# 306        1
# Name: amnt_loans30, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="amnt_loans30",data=mcp)
# Out:
# <AxesSubplot: xlabel='amnt_loans30', ylabel='count'>

# %% [markdown]
# amnt_loans30(Total amount of loans taken by user in last 30 days) is highest in 6.

# %%
sns.lineplot(x="amnt_loans30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='amnt_loans30', ylabel='label'>

# %% [markdown]
# amnt_loans30(Total amount of loans taken by user in last 30 days) is higher in 1(success) type of label.

# %%
mcp["maxamnt_loans30"].value_counts()
# Out:
# 6.00000        179193
# 12.00000        26109
# 0.00000          3244
# 17083.99814         1
# 62511.75070         1
#                 ...
# 30346.38585         1
# 66821.81906         1
# 55716.81724         1
# 41580.15663         1
# 96927.24325         1
# Name: maxamnt_loans30, Length: 1050, dtype: int64

# %%
sns.histplot(mcp["maxamnt_loans30"])
# Out:
# <AxesSubplot: xlabel='maxamnt_loans30', ylabel='Count'>

# %% [markdown]
# maxamnt_loans30(maximum amount of loan taken by the user in last 30 days) is highest in between 0 to 10.

# %%
sns.jointplot(x="maxamnt_loans30",y="label",data=mcp,kind="hex")

# %% [markdown]
# maxamnt_loans30(maximum amount of loan taken by the user in last 30 days) is highest in 1(success) type of label.

# %%
mcp["medianamnt_loans30"].value_counts()
# Out:
# 0.0    195445
# 1.0      7149
# 0.5      6538
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64

# %%
sns.countplot(x="medianamnt_loans30",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianamnt_loans30', ylabel='count'>

# %% [markdown]
# medianamnt_loans30(Median of amounts of loan taken by the user in last 30 days) is higher in 0.0

# %%
sns.pointplot(x="medianamnt_loans30",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianamnt_loans30', ylabel='label'>

# %% [markdown]
# medianamnt_loans30(Median of amounts of loan taken by the user in last 30 days) is higher in 1(success) type of label.

# %%
mcp["cnt_loans90"].value_counts()
# Out:
# 1.000000       73862
# 2.000000       37286
# 3.000000       23986
# 4.000000       16761
# 5.000000       12331
#                ...
# 3940.313295        1
# 2547.650840        1
# 2925.920310        1
# 1757.322504        1
# 2047.902454        1
# Name: cnt_loans90, Length: 1110, dtype: int64

# %%
sns.catplot(x="cnt_loans90",data=mcp)

# %% [markdown]
# cnt_loans90(Number of loans taken by user in last 90 days) is highest in 0 to 10

# %%
sns.scatterplot(x="cnt_loans90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='cnt_loans90', ylabel='label'>

# %% [markdown]
# 1(success) and 0(failure)both are highest in between 1000 to 5000.

# %%
mcp["amnt_loans90"].value_counts()
# Out:
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 438        1
# 360        1
# 372        1
# 402        1
# 426        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %%
sns.violinplot(x="amnt_loans90",data=mcp)
# Out:
# <AxesSubplot: xlabel='amnt_loans90'>

# %% [markdown]
# amnt_loans90(Total amount of loans taken by user in last 90 days) is highest in 0 to 50.

# %%
sns.jointplot(x="amnt_loans90",y="label",data=mcp)

# %% [markdown]
# Data of amnt_loans90(Total amount of loans taken by user in last 90 days) is higher in 1(success).

# %%
mcp["maxamnt_loans90"].value_counts()
# Out:
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %%
sns.countplot(x="maxamnt_loans90",data=mcp)
# Out:
# <AxesSubplot: xlabel='maxamnt_loans90', ylabel='count'>

# %% [markdown]
# maxamnt_loans90(maximum amount of loan taken by the user in last 90 days) is highest in 6.

# %%
sns.histplot(x="maxamnt_loans90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='maxamnt_loans90', ylabel='label'>

# %% [markdown]
# Data of maxamnt_loans90(maximum amount of loan taken by the user in last 90 days) is higher in 1(success).

# %%
mcp["medianamnt_loans90"].value_counts()
# Out:
# 0.0    197424
# 1.0      6172
# 0.5      5668
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64

# %%
sns.histplot(mcp["medianamnt_loans90"])
# Out:
# <AxesSubplot: xlabel='medianamnt_loans90', ylabel='Count'>

# %% [markdown]
# medianamnt_loans90(Median of amounts of loan taken by the user in last 90 days) data is highest in 0.0.

# %%
sns.lineplot(x="medianamnt_loans90",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='medianamnt_loans90', ylabel='label'>

# %% [markdown]
# Data of medianamnt_loans90(Median of amounts of loan taken by the user in last 90 days) is higher in 1(success) type of label.

# %%
mcp["payback30"].value_counts()
# Out:
# 0.000000     106712
# 2.000000       5601
# 3.000000       5023
# 4.000000       3931
# 2.500000       3518
#               ...
# 4.545455          1
# 48.400000         1
# 3.133333          1
# 1.518519          1
# 5.615385          1
# Name: payback30, Length: 1363, dtype: int64

# %%
sns.distplot(mcp["payback30"])
# Out:
# <AxesSubplot: xlabel='payback30', ylabel='Density'>

# %% [markdown]
# Data of payback30(Average payback time in days over last 30 days) is skewed.

# %%
sns.displot(x="payback30",y="label",data=mcp)

# %% [markdown]
# payback30(Average payback time in days over last 30 days), 1(success) data is in between 0 to 175 and payback30(Average payback time in days over last 30 days), 0(failure) data is in between 0 to 150.

# %%
mcp["payback90"].value_counts()
# Out:
# 0.000000     95699
# 2.000000      4982
# 3.000000      4437
# 4.000000      3610
# 2.500000      3015
#              ...
# 35.625000        1
# 48.400000        1
# 8.363636         1
# 62.666667        1
# 25.846154        1
# Name: payback90, Length: 2381, dtype: int64

# %%
sns.violinplot(x="payback90",data=mcp)
# Out:
# <AxesSubplot: xlabel='payback90'>

# %% [markdown]
# payback90(Average payback time in days over last 90 days) is higher in between 0 to 20.

# %%
sns.jointplot(x="payback90",y="label",data=mcp)

# %% [markdown]
# payback90(Average payback time in days over last 90 days) , 1(success) is higher.

# %%
mcp["pcircle"].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %% [markdown]
# only on type of pcircle(telecom circle).

# %%
sns.histplot(x="pcircle",y="label",data=mcp)
# Out:
# <AxesSubplot: xlabel='pcircle', ylabel='label'>

# %% [markdown]
# pcircle(telecom circle) have only on type so we can drop this column.

# %%
mcp.drop("pcircle",axis=1,inplace=True)

# %%
mcp.keys()
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pdate'],
#       dtype='object')

# %% [markdown]
# pcircle column has been drop.

# %%
mcp["pdate"].value_counts()
# Out:
# 04-07-2016    3150
# 05-07-2016    3127
# 07-07-2016    3116
# 20-06-2016    3099
# 17-06-2016    3082
#               ...
# 04-06-2016    1559
# 18-08-2016    1407
# 19-08-2016    1132
# 20-08-2016     788
# 21-08-2016     324
# Name: pdate, Length: 82, dtype: int64

# %% [markdown]
# pdate not affect the label so we can drop this column.

# %%
mcp.drop("pdate",axis=1,inplace=True)

# %%
mcp.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90'],
#       dtype='object')

# %% [markdown]
# pdate column has been dropped.

# %%
mcp.skew().sort_values(ascending=False)
# Out:
# medianmarechprebal90    44.880503
# fr_da_rech90            28.988083
# cnt_da_rech90           27.267278
# cnt_da_rech30           17.818364
# maxamnt_loans30         17.658052
# cnt_loans90             16.594408
# last_rech_date_da       14.814857
# last_rech_date_ma       14.790974
# medianmarechprebal30    14.779875
# fr_da_rech30            14.776430
# fr_ma_rech30            14.772833
# aon                     10.392949
# payback30                8.310695
# payback90                6.899951
# sumamnt_ma_rech30        6.386787
# sumamnt_ma_rech90        4.897950
# medianamnt_loans90       4.895720
# medianamnt_loans30       4.551043
# rental30                 4.521929
# rental90                 4.437681
# daily_decr90             4.252565
# daily_decr30             3.946230
# last_rech_amt_ma         3.781149
# medianamnt_ma_rech90     3.752706
# medianamnt_ma_rech30     3.512324
# cnt_ma_rech90            3.425254
# cnt_ma_rech30            3.283842
# ...

# %% [markdown]
# skewness is very high in most of the columns.

# %%
mcp.plot(kind="density",subplots=True,layout=(4,10),figsize=(18,12))
plt.show()

# %% [markdown]
# # Removing The Skewness

# %%
mcp.head(3).T
# Out:
#                             0         1        2
# label                    0.00      1.00     1.00
# aon                    272.00    712.00   535.00
# daily_decr30          3055.05  12122.00  1398.00
# daily_decr90          3065.15  12124.75  1398.00
# rental30               220.13   3691.26   900.13
# rental90               260.13   3691.26   900.13
# last_rech_date_ma        2.00     20.00     3.00
# last_rech_date_da        0.00      0.00     0.00
# last_rech_amt_ma      1539.00   5787.00  1539.00
# cnt_ma_rech30            2.00      1.00     1.00
# fr_ma_rech30            21.00      0.00     0.00
# sumamnt_ma_rech30     3078.00   5787.00  1539.00
# medianamnt_ma_rech30  1539.00   5787.00  1539.00
# medianmarechprebal30     7.50     61.04    66.32
# cnt_ma_rech90            2.00      1.00     1.00
# fr_ma_rech90            21.00      0.00     0.00
# sumamnt_ma_rech90     3078.00   5787.00  1539.00
# medianamnt_ma_rech90  1539.00   5787.00  1539.00
# ...

# %%
x=mcp.drop("label",axis=1)

# %%
x.head(2)
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0  272.0       3055.05       3065.15    220.13    260.13                2.0
# 1  712.0      12122.00      12124.75   3691.26   3691.26               20.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                0.0              1539              2          21.0  ...
# 1                0.0              5787              1           0.0  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 0            2            12              6.0                 0.0
# 1            1            12             12.0                 0.0
#
#    cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0          2.0            12                6                 0.0       29.0
# 1          1.0            12               12                 0.0        0.0
#
#    payback90
# 0       29.0
# 1        0.0
#
# [2 rows x 32 columns]

# %%
from sklearn.preprocessing import power_transform , PowerTransformer

# %%
PowerTransformer()
# Out:
# PowerTransformer()

# %%
x_new=power_transform(x)
print(x_new)
# Out:
# [[-0.17711186  0.332156    0.29918138 ... -0.24827185  1.8132661
#    1.7839639 ]
#  [ 0.03645291  1.11602076  1.04508396 ... -0.24827185 -0.93740539
#   -1.01891694]
#  [-0.03465905 -0.00750823 -0.02820273 ... -0.24827185 -0.93740539
#   -1.01891694]
#  ...
#  [ 0.13457681  1.10045475  1.03342362 ... -0.24827185  0.97429196
#    0.75293936]
#  [ 0.30910144  1.13605673  1.06838078 ... -0.24827185 -0.93740539
#    1.3378306 ]
#  [ 0.27706283  0.52502128  0.48715657 ... -0.24827185 -0.93740539
#   -1.01891694]]

# %% [markdown]
# # Checking skewness

# %%
x=pd.DataFrame(x_new,columns=x.columns).skew()

# %%
print(x)
# Out:
# aon                       1.654517
# daily_decr30             -6.582718
# daily_decr90             -7.080191
# rental30                 -1.022844
# rental90                 -0.962717
# last_rech_date_ma        -5.362530
# last_rech_date_da      -106.606657
# last_rech_amt_ma         -0.061262
# cnt_ma_rech30            -0.000145
# fr_ma_rech30              0.165015
# sumamnt_ma_rech30        -0.291322
# medianamnt_ma_rech30     -0.189628
# medianmarechprebal30     -0.119058
# cnt_ma_rech90            -0.002465
# fr_ma_rech90              0.142952
# sumamnt_ma_rech90        -0.192158
# medianamnt_ma_rech90     -0.044604
# medianmarechprebal90      7.506286
# cnt_da_rech30             6.925820
# fr_da_rech30             11.390665
# cnt_da_rech90             6.006577
# fr_da_rech90             15.469700
# cnt_loans30               0.036243
# amnt_loans30              0.001948
# maxamnt_loans30          -1.680107
# medianamnt_loans30        3.447735
# cnt_loans90               0.105580
# ...

# %% [markdown]
# After using power transformer skewness is present in last_rech_date_da,fr_da_rech30, fr_da_rech90 column.

# %%
sns.distplot(mcp["last_rech_date_da"])
# Out:
# <AxesSubplot: xlabel='last_rech_date_da', ylabel='Density'>

# %%
#using Log Transfomation for skewness

mcp["last_rech_date_da"]=np.log(1+mcp["last_rech_date_da"])

# %%
mcp["last_rech_date_da"].skew()
# Out:
# nan

# %%
sns.distplot(mcp["fr_da_rech30"])
# Out:
# <AxesSubplot: xlabel='fr_da_rech30', ylabel='Density'>

# %%
sns.distplot(mcp["fr_da_rech90"])
# Out:
# <AxesSubplot: xlabel='fr_da_rech90', ylabel='Density'>

# %%
#using Log Transfomation for skewness

mcp["fr_da_rech90"]=np.log(1+mcp["fr_da_rech90"])

# %%
sns.distplot(mcp["fr_da_rech90"])
# Out:
# <AxesSubplot: xlabel='fr_da_rech90', ylabel='Density'>

# %% [markdown]
# by using log_transformation method skewness is not removing.

# %% [markdown]
# # Checking outliers

# %%
mcp.plot(kind="box",subplots=True,layout=(4,10))
# Out:
# label                       AxesSubplot(0.125,0.71587;0.065678x0.16413)
# aon                      AxesSubplot(0.203814,0.71587;0.065678x0.16413)
# daily_decr30             AxesSubplot(0.282627,0.71587;0.065678x0.16413)
# daily_decr90             AxesSubplot(0.361441,0.71587;0.065678x0.16413)
# rental30                 AxesSubplot(0.440254,0.71587;0.065678x0.16413)
# rental90                 AxesSubplot(0.519068,0.71587;0.065678x0.16413)
# last_rech_date_ma        AxesSubplot(0.597881,0.71587;0.065678x0.16413)
# last_rech_date_da        AxesSubplot(0.676695,0.71587;0.065678x0.16413)
# last_rech_amt_ma         AxesSubplot(0.755508,0.71587;0.065678x0.16413)
# cnt_ma_rech30            AxesSubplot(0.834322,0.71587;0.065678x0.16413)
# fr_ma_rech30               AxesSubplot(0.125,0.518913;0.065678x0.16413)
# sumamnt_ma_rech30       AxesSubplot(0.203814,0.518913;0.065678x0.16413)
# medianamnt_ma_rech30    AxesSubplot(0.282627,0.518913;0.065678x0.16413)
# ...

# %% [markdown]
# Outliers are present in micro credit dataset.

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
mcp["last_rech_date_da"].isnull().sum()
# Out:
# 11

# %%
mcp["last_rech_date_da"].mean()
# Out:
# -inf

# %%
mcp.drop("last_rech_date_da",axis=1,inplace=True)

# %%
new_data=np.array(mcp)

# %%
new_data
# Out:
# array([[0.00000000e+00, 2.72000000e+02, 3.05505000e+03, ...,
#         0.00000000e+00, 2.90000000e+01, 2.90000000e+01],
#        [1.00000000e+00, 7.12000000e+02, 1.21220000e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 5.35000000e+02, 1.39800000e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [1.00000000e+00, 1.01300000e+03, 1.18431117e+04, ...,
#         0.00000000e+00, 4.00000000e+00, 3.83333333e+00],
#        [1.00000000e+00, 1.73200000e+03, 1.24882283e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 1.05000000e+01],
#        [1.00000000e+00, 1.58100000e+03, 4.48936200e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
z=np.abs(zscore(mcp))
z.head()
# Out:
#       label       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0  2.647896  0.103577      0.252299      0.276346  0.573844  0.558583
# 1  0.377658  0.097764      0.731037      0.553380  0.231788  0.036020
# 2  0.377658  0.100102      0.432011      0.429033  0.416020  0.447674
# 3  0.377658  0.103986      0.581326      0.555125  0.587935  0.576036
# 4  0.377658  0.094660      0.567293      0.543274  0.369886  0.413227
#
#    last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0           0.069637          0.221637       0.464760      0.069279  ...
# 1           0.069303          1.570178       0.699718      0.069670  ...
# 2           0.069619          0.221637       0.699718      0.069670  ...
# 3           0.068914          0.471344       0.934677      0.069670  ...
# 4           0.069600          0.103151       0.710030      0.069633  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# ...

# %%
thereshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([14, 14, 31, ..., 27, 25, 29], dtype=int64))

# %%
new_data=mcp[(z<3).all(axis=1)]
new_data
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# ...

# %%
new_data.shape
# Out:
# (162258, 32)

# %%
mcp.shape
# Out:
# (209593, 32)

# %% [markdown]
# 47335 rows has been dropped. it means outliers has been removed.

# %%
mcp=new_data

# %%
mcp.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                2.0              1539              2          21.0  ...
# 1               20.0              5787              1           0.0  ...
# 2                3.0              1539              1           0.0  ...
# 3               41.0               947              0           0.0  ...
# 4                4.0              2309              7           2.0  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 0            2            12              6.0                 0.0
# ...

# %%
x=mcp.drop("label",axis=1)

# %%
x.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0  272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 1  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 2  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 3  241.0     21.228000     21.228000    159.42    159.42               41.0
# 4  947.0    150.619333    150.619333   1098.90   1098.90                4.0
#
#    last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# 0              1539              2          21.0             3078.0  ...
# 1              5787              1           0.0             5787.0  ...
# 2              1539              1           0.0             1539.0  ...
# 3               947              0           0.0                0.0  ...
# 4              2309              7           2.0            20029.0  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# ...

# %% [markdown]
# # MULTICOLLINEARITY WITH VARIANCE INFLATION FACTOR

# %%
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif(x):
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
vif(x)
# Out:
#                variables   VIF FACTOR
# 0                    aon     2.693484
# 1           daily_decr30    45.514458
# 2           daily_decr90    49.428824
# 3               rental30    18.843478
# 4               rental90    20.300042
# 5      last_rech_date_ma     1.905194
# 6       last_rech_amt_ma     7.243129
# 7          cnt_ma_rech30    31.790445
# 8           fr_ma_rech30     1.986040
# 9      sumamnt_ma_rech30    23.782578
# 10  medianamnt_ma_rech30    12.005230
# 11  medianmarechprebal30     2.492057
# 12         cnt_ma_rech90    32.994328
# 13          fr_ma_rech90     1.758161
# 14     sumamnt_ma_rech90    25.219073
# 15  medianamnt_ma_rech90    12.520000
# 16  medianmarechprebal90     2.737449
# 17         cnt_da_rech30     1.000544
# 18          fr_da_rech30          NaN
# 19         cnt_da_rech90     1.025799
# 20          fr_da_rech90          NaN
# 21           cnt_loans30  1696.713771
# 22          amnt_loans30  1866.233569
# 23       maxamnt_loans30     1.002965
# ...

# %% [markdown]
# High multicollinearty in amnt_loans90, cnt_loans90, amnt_loans30 and cnt_loans30.

# %%
mcp=mcp.drop("amnt_loans90",axis=1)

# %%
mcp.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                2.0              1539              2          21.0  ...
# 1               20.0              5787              1           0.0  ...
# 2                3.0              1539              1           0.0  ...
# 3               41.0               947              0           0.0  ...
# 4                4.0              2309              7           2.0  ...
#
#    fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0           0.0            2            12              6.0
# ...

# %%
x=mcp.drop("label",axis=1)

# %%
x.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0  272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 1  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 2  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 3  241.0     21.228000     21.228000    159.42    159.42               41.0
# 4  947.0    150.619333    150.619333   1098.90   1098.90                4.0
#
#    last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# 0              1539              2          21.0             3078.0  ...
# 1              5787              1           0.0             5787.0  ...
# 2              1539              1           0.0             1539.0  ...
# 3               947              0           0.0                0.0  ...
# 4              2309              7           2.0            20029.0  ...
#
#    fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# ...

# %%
def vif(x):
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
vif(x)
# Out:
#                variables  VIF FACTOR
# 0                    aon    2.693081
# 1           daily_decr30   43.491146
# 2           daily_decr90   47.249870
# 3               rental30   18.843443
# 4               rental90   20.300023
# 5      last_rech_date_ma    1.905193
# 6       last_rech_amt_ma    7.243076
# 7          cnt_ma_rech30   31.785986
# 8           fr_ma_rech30    1.986004
# 9      sumamnt_ma_rech30   23.782223
# 10  medianamnt_ma_rech30   12.003318
# 11  medianmarechprebal30    2.492006
# 12         cnt_ma_rech90   32.980043
# 13          fr_ma_rech90    1.758097
# 14     sumamnt_ma_rech90   25.212000
# 15  medianamnt_ma_rech90   12.514895
# 16  medianmarechprebal90    2.737446
# 17         cnt_da_rech30    1.000543
# 18          fr_da_rech30         NaN
# 19         cnt_da_rech90    1.025799
# 20          fr_da_rech90         NaN
# 21           cnt_loans30   85.815647
# 22          amnt_loans30   75.220344
# 23       maxamnt_loans30    1.002962
# ...

# %% [markdown]
# Now no high multicollinearty in Dataset.

# %% [markdown]
# # Scaling The data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[-0.75413003, -0.12636341, -0.16953599, ..., -0.15975427,
#          6.23920556,  5.20773251],
#        [ 0.13218376,  1.47557364,  1.23550483, ..., -0.15975427,
#         -0.61920426, -0.64691626],
#        [-0.2243561 , -0.41912887, -0.42809197, ..., -0.15975427,
#         -0.61920426, -0.64691626],
#        ...,
#        [ 0.73850297,  1.42630001,  1.2013233 , ..., -0.15975427,
#          0.3267833 ,  0.1269741 ],
#        [ 2.18682028,  1.54027839,  1.30523577, ..., -0.15975427,
#         -0.61920426,  1.47287037],
#        [ 1.8826535 ,  0.12704899,  0.0583931 , ..., -0.15975427,
#         -0.61920426, -0.64691626]])

# %% [markdown]
# # Prediction by the algorithm

# %%
mcp.tail()
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 209588                1.0              4048              3           2.0  ...
# 209589                4.0               773              4           1.0  ...
# 209590                3.0              1539              5           8.0  ...
# 209591                2.0               773              5           4.0  ...
# 209592               13.0              7526              2           1.0  ...
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# ...

# %%
x=mcp.drop("label",axis=1)

# %%
x.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0  272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 1  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 2  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 3  241.0     21.228000     21.228000    159.42    159.42               41.0
# 4  947.0    150.619333    150.619333   1098.90   1098.90                4.0
#
#    last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# 0              1539              2          21.0             3078.0  ...
# 1              5787              1           0.0             5787.0  ...
# 2              1539              1           0.0             1539.0  ...
# 3               947              0           0.0                0.0  ...
# 4              2309              7           2.0            20029.0  ...
#
#    fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# ...

# %%
y=mcp["label"]

# %%
y.tail()
# Out:
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=41)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (113580, 30)
# (113580,)
# (48678, 30)
# (48678,)

# %%
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [raw]
# RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfcpred=rfc.predict(x_test)
print(accuracy_score(y_test,rfcpred)*100)
print(classification_report(y_test,rfcpred))
print(confusion_matrix(y_test,rfcpred))
# Out:
# 90.79871810674226
#               precision    recall  f1-score   support
#
#            0       0.76      0.48      0.59      6701
#            1       0.92      0.98      0.95     41977
#
#     accuracy                           0.91     48678
#    macro avg       0.84      0.73      0.77     48678
# weighted avg       0.90      0.91      0.90     48678
#
# [[ 3244  3457]
#  [ 1022 40955]]

# %% [raw]
# DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpred)*100)
print(classification_report(y_test,dtcpred))
print(confusion_matrix(y_test,dtcpred))
# Out:
# 85.80262130736678
#               precision    recall  f1-score   support
#
#            0       0.49      0.53      0.50      6701
#            1       0.92      0.91      0.92     41977
#
#     accuracy                           0.86     48678
#    macro avg       0.70      0.72      0.71     48678
# weighted avg       0.86      0.86      0.86     48678
#
# [[ 3521  3180]
#  [ 3731 38246]]

# %% [raw]
# KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn)*100)
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 87.46456304696166
# [[ 2558  4143]
#  [ 1959 40018]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.38      0.46      6701
#            1       0.91      0.95      0.93     41977
#
#     accuracy                           0.87     48678
#    macro avg       0.74      0.67      0.69     48678
# weighted avg       0.86      0.87      0.86     48678

# %% [raw]
# SVC

# %%
svc=SVC()
svc.fit(x_train,y_train)
svcpred=svc.predict(x_test)
print(accuracy_score(y_test,svcpred)*100)
print(classification_report(y_test,svcpred))
print(confusion_matrix(y_test,svcpred))
# Out:
# 86.43740498787955
#               precision    recall  f1-score   support
#
#            0       0.68      0.03      0.05      6701
#            1       0.87      1.00      0.93     41977
#
#     accuracy                           0.86     48678
#    macro avg       0.77      0.51      0.49     48678
# weighted avg       0.84      0.86      0.81     48678
#
# [[  187  6514]
#  [   88 41889]]

# %% [markdown]
# RandomForestClassifier is working well.

# %% [markdown]
# # Cross val score

# %%
from sklearn.model_selection import cross_val_score

# %% [raw]
# RandomForestClassifier

# %%
score=cross_val_score(rfc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.90693948 0.90592259 0.90706274 0.90869311 0.90684417]
# 0.9070924167217524
# 0.0008962805250657778

# %% [raw]
# DecisionTreeClassifier

# %%
score=cross_val_score(dtc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.86111796 0.85868359 0.85822137 0.86068226 0.85593664]
# 0.8589283657025906
# 0.001864436531379286

# %% [raw]
# KNeighborsClassifier

# %%
score=cross_val_score(knn,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.87612474 0.87304326 0.87347467 0.87424116 0.87498074]
# 0.8743729152095636
# 0.0010982267169298305

# %% [markdown]
# # Grid search CV

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# RandomForestClassifier

# %%
p1={"n_estimators":[100,200,300],"criterion":["gini","entropy","log_loss"],"class_weight":["balanced","balanced_subsample",None],"max_samples":[None,1,2.1,2.0]}

# %%
gd=GridSearchCV(estimator=rfc,param_grid=p1,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print(gd.best_score_)
# Out:
# {'class_weight': None, 'criterion': 'entropy', 'max_samples': None, 'n_estimators': 300}
# 0.9075916170577907

# %%
rfc=RandomForestClassifier(class_weight=None,criterion="entropy",max_samples=None,n_estimators=300)
rfc.fit(x_train,y_train)
rfcpred=rfc.predict(x_test)
print(accuracy_score(y_test,rfcpred)*100)
print(classification_report(y_test,rfcpred))
print(confusion_matrix(y_test,rfcpred))
# Out:
# 90.77612062944246
#               precision    recall  f1-score   support
#
#            0       0.76      0.48      0.59      6701
#            1       0.92      0.98      0.95     41977
#
#     accuracy                           0.91     48678
#    macro avg       0.84      0.73      0.77     48678
# weighted avg       0.90      0.91      0.90     48678
#
# [[ 3201  3500]
#  [  990 40987]]

# %% [markdown]
# DecisionTreeClassifier

# %%
p2={"criterion":["gini","entropy","log_loss"],"splitter":["best","random"],"min_impurity_decrease":[0.0,0.1,0.3],"max_leaf_nodes":[None,1,2,3]}

# %%
gd=GridSearchCV(estimator=dtc,param_grid=p2,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print(gd.best_score_)
# Out:
# {'criterion': 'entropy', 'max_leaf_nodes': 2, 'min_impurity_decrease': 0.0, 'splitter': 'best'}
# 0.8938110846871528

# %%
dtc=DecisionTreeClassifier(criterion="entropy",max_leaf_nodes=2,min_impurity_decrease=0.0,splitter="best")
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpred)*100)
print(classification_report(y_test,dtcpred))
print(confusion_matrix(y_test,dtcpred))
# Out:
# 89.39767451415423
#               precision    recall  f1-score   support
#
#            0       0.84      0.28      0.42      6701
#            1       0.90      0.99      0.94     41977
#
#     accuracy                           0.89     48678
#    macro avg       0.87      0.64      0.68     48678
# weighted avg       0.89      0.89      0.87     48678
#
# [[ 1892  4809]
#  [  352 41625]]

# %% [markdown]
# KNeighborsClassifier

# %%
p3={"n_jobs":[None,1,2,3],"p":[2,4,6],"leaf_size":[30,40,50],"algorithm":["auto","ball_tree","kd_tree","brute"],"weights":["uniform","distance"]}

# %% [raw]
# gd=GridSearchCV(estimator=knn,param_grid=p3,cv=5)
# gd.fit(x,y)
# print(gd.best_params_)
# print(gd.best_score_)

# %% [raw]
# knc=KNeighborsClassifier(n_jobs=None,algorithm="auto",leaf_size=30,weights="uniform",p=6)
# knc.fit(x_train,y_train)
# kncpred=knc.predict(x_test)
# print(accuracy_score(y_test,kncpred)*100)
# print(classification_report(y_test,kncpred))
# print(confusion_matrix(y_test,kncpred))

# %% [markdown]
# This code is not interrupting

# %% [markdown]
# SVC

# %%
p4={"break_ties":[True,False],"decision_function_shape":["ovo","ovr"],"max_iter":[1,2,3,4],"verbose":[False,True]}

# %%
gd=GridSearchCV(estimator=svc,param_grid=p4,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print(gd.best_score_)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]{'break_ties': True, 'decision_function_shape': 'ovr', 'max_iter': 2, 'verbose': False}
# 0.45112199161148486

# %%
svc=SVC(break_ties=True,decision_function_shape="ovr",max_iter=2,verbose=False)
svc.fit(x_train,y_train)
svcpred=svc.predict(x_test)
print(accuracy_score(y_test,svcpred)*100)
print(classification_report(y_test,svcpred))
print(confusion_matrix(y_test,svcpred))
# Out:
# 67.28090718599779
#               precision    recall  f1-score   support
#
#            0       0.15      0.30      0.20      6701
#            1       0.87      0.73      0.79     41977
#
#     accuracy                           0.67     48678
#    macro avg       0.51      0.52      0.50     48678
# weighted avg       0.77      0.67      0.71     48678
#
# [[ 1992  4709]
#  [11218 30759]]

# %% [markdown]
# After Using Grid Search Cv RandomforestClassifier is working well.

# %% [markdown]
# # Saving the best model

# %%
import pickle

# %%
file="micro_credit_loan_prediction"
pickle.dump(rfc,open(file,"wb"))

# %% [markdown]
# # Loading The best model

# %%
load_model=pickle.load(open(file,"rb"))

# %%
load_model.predict(x_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)
